# %%
# %pylab inline
font = {'size':18, 'family':'serif'}
matplotlib.rc('font', **font)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
willman1 = genfromtxt('../willman1.csv', delimiter=',')

# %%
shape(willman1)
# Out:
# (27457, 7)

# %%
ra_will1 = willman1[:,0]
dec_will1 = willman1[:,1]

# %%
figure(figsize=(6,6))
title('Willman I', fontsize=22)
scatter(ra_will1, dec_will1, s=0.1, c='k')
xlabel('RA$^{\circ}$')
ylabel('DEC$^{\circ}$')
